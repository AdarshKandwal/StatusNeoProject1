# %%
import pandas as pd

# %%
banglore=pd.read_csv('Bangalore.csv')
chennai=pd.read_csv('Chennai.csv')
delhi=pd.read_csv('Delhi.csv')
hyderabad=pd.read_csv('Hyderabad.csv')
kolkata=pd.read_csv('Mumbai.csv')

# %%
banglore.head()
# Out:
#       Price  Area  ... Wardrobe  Refrigerator
# 0  30000000  3340  ...        0             0
# 1   7888000  1045  ...        0             0
# 2   4866000  1179  ...        0             0
# 3   8358000  1675  ...        0             0
# 4   6845000  1670  ...        0             0
#
# [5 rows x 40 columns]

# %%
delhi.head()
# Out:
#       Price  Area          Location  ...  Sofa  Wardrobe  Refrigerator
# 0  10500000  1200  Sector 10 Dwarka  ...     0         0             0
# 1   6000000  1000       Uttam Nagar  ...     0         0             0
# 2  15000000  1350      Sarita Vihar  ...     0         0             0
# 3   2500000   435       Uttam Nagar  ...     0         0             0
# 4   5800000   900        Dwarka Mor  ...     0         0             0
#
# [5 rows x 40 columns]

# %%
kolkata.head()
# Out:
#      Price  Area  Location  ...  Sofa  Wardrobe  Refrigerator
# 0  4850000   720  Kharghar  ...     0         0             0
# 1  4500000   600  Kharghar  ...     0         0             0
# 2  6700000   650  Kharghar  ...     0         0             0
# 3  4500000   650  Kharghar  ...     0         1             0
# 4  5000000   665  Kharghar  ...     0         0             0
#
# [5 rows x 40 columns]

# %%
import seaborn as sns

# %% [markdown]
# <h5>1.Describing the Data we will be working on For ex:-for Banglore we can average number of bedrooms are 2 and minimum is 1. </h5>

# %%
banglore.describe()
# Out:
#               Price         Area  ...     Wardrobe  Refrigerator
# count  6.207000e+03  6207.000000  ...  6207.000000   6207.000000
# mean   1.058510e+07  1526.094248  ...     6.171097      6.210569
# std    1.410943e+07   764.845609  ...     4.178546      4.124430
# min    2.000000e+06   415.000000  ...     0.000000      0.000000
# 25%    5.000000e+06  1110.000000  ...     0.000000      0.000000
# 50%    7.368000e+06  1340.000000  ...     9.000000      9.000000
# 75%    1.070000e+07  1662.500000  ...     9.000000      9.000000
# max    3.000000e+08  9900.000000  ...     9.000000      9.000000
#
# [8 rows x 39 columns]

# %%
dfbanglore =banglore.sample(frac =.60) 
priceBanglore=dfbanglore['Price']
maintainceStaffbanglore=dfbanglore['Area']

# %%
sns.distplot(priceBanglore)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dfbanglore['Price'],kde=False,bins=60)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(x='Price',y='Area',data=dfbanglore,kind='reg')

# %%
sns.jointplot(x='Price',y='Area',data=dfbanglore,kind='scatter')

# %%
import numpy as np
pricebang=np.array(banglore['Price'])
pricechennai=np.array(chennai['Price'])
pricedelhi=np.array(delhi['Price'])
pricehyderabad=np.array(hyderabad['Price'])
pricekolkata=np.array(kolkata['Price'])

# %%
pricebang.sort()
pricechennai.sort()
pricedelhi.sort()
pricehyderabad.sort()
pricekolkata.sort()

# %%
from matplotlib import pyplot as plt
delhi.sort_values(by=['Price'],inplace=True)
df=delhi[-10:]

# %%
plt.plot(df['Area'],df['Price'],label="banglore")

# %%
#finding out correlated data
print(banglore.corr())
df=banglore[['Price', 'Area','No. of Bedrooms']]
# Out:
#                         Price      Area  ...  Wardrobe  Refrigerator
# Price                1.000000  0.397626  ...  0.030335      0.033460
# Area                 0.397626  1.000000  ...  0.009288      0.013166
# No. of Bedrooms      0.234272  0.733010  ...  0.024300      0.027576
# Resale              -0.038024  0.021379  ... -0.033874     -0.036538
# MaintenanceStaff     0.030497  0.008910  ...  0.999025      0.998159
# Gymnasium            0.031976  0.011436  ...  0.999217      0.998334
# SwimmingPool         0.034450  0.014659  ...  0.998554      0.997864
# LandscapedGardens    0.029744  0.011841  ...  0.997692      0.996873
# JoggingTrack         0.035339  0.016572  ...  0.997853      0.996902
# RainWaterHarvesting  0.033558  0.012948  ...  0.997617      0.996563
# IndoorGames          0.033942  0.013533  ...  0.997490      0.996653
# ShoppingMall         0.029271  0.008135  ...  0.999066      0.997967
# Intercom             0.030951  0.008993  ...  0.998221      0.997658
# ...

# %%
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)

# %%
sns.heatmap(df.corr(),annot=True)

# %%
sns.lmplot(x='Area',y='Price',data=banglore,palette='coolwarm')
